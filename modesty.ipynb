# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as pltdata2.drop(['Unnamed: 0','Product_Identifier','Supermarket_Identifier','Product_Supermarket_Identifier'], axis = 1, inplace = True)

# %%
data = pd.read_csv('dat_feature.xls')

# %%
data.head(2)
# Out:
#    Unnamed: 0 Product_Identifier Supermarket_Identifier  \
# 0           0              DRA12            CHUKWUDI010
# 1           1              DRA12            CHUKWUDI013
#
#   Product_Supermarket_Identifier  Product_Weight  Product_Fat_Content  \
# 0              DRA12_CHUKWUDI010            11.6                    0
# 1              DRA12_CHUKWUDI013            11.6                    0
#
#    Product_Shelf_Visibility Product_Type  Product_Price  \
# 0                  0.068535  Soft Drinks         357.54
# 1                  0.040912  Soft Drinks         355.79
#
#    Supermarket_Opening_Year  Supermarket _Size Supermarket_Location_Type  \
# 0                      2005                2.0                 Cluster 3
# 1                      1994                0.0                 Cluster 3
#
#     Supermarket_Type  Product_Supermarket_Sales
# 0      Grocery Store                     709.08
# 1  Supermarket Type1                    6381.69

# %%
# drop supermarket size

# %%
test = pd.read_csv('test_feature.xls')

# %%
test.head(2)
# Out:
#    Unnamed: 0 Product_Identifier Supermarket_Identifier  \
# 0           0              DRA59            CHUKWUDI010
# 1           1              DRA59            CHUKWUDI013
#
#   Product_Supermarket_Identifier  Product_Weight  Product_Fat_Content  \
# 0              DRA59_CHUKWUDI010            8.27                    2
# 1              DRA59_CHUKWUDI013            8.27                    2
#
#    Product_Shelf_Visibility Product_Type  Product_Price  \
# 0                  0.214125  Soft Drinks         459.98
# 1                  0.127821  Soft Drinks         464.98
#
#    Supermarket_Opening_Year  Supermarket _Size Supermarket_Location_Type  \
# 0                      2005                2.0                 Cluster 3
# 1                      1994                0.0                 Cluster 3
#
#     Supermarket_Type
# 0      Grocery Store
# 1  Supermarket Type1

# %%
data.drop(['Unnamed: 0','Product_Identifier','Supermarket_Identifier','Product_Supermarket_Identifier','Product_Type'], axis = 1, inplace = True)

# %%
test.drop(['Unnamed: 0','Product_Identifier','Supermarket_Identifier','Product_Supermarket_Identifier','Product_Type'], axis = 1, inplace = True)

# %%
data.head(2)
# Out:
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
#
#    Product_Price  Supermarket_Opening_Year  Supermarket _Size  \
# 0         357.54                      2005                2.0
# 1         355.79                      1994                0.0
#
#   Supermarket_Location_Type   Supermarket_Type  Product_Supermarket_Sales
# 0                 Cluster 3      Grocery Store                     709.08
# 1                 Cluster 3  Supermarket Type1                    6381.69

# %%
data.drop('Supermarket _Size', axis = 1, inplace = True)

test.drop('Supermarket _Size', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    1                  0.000000
#
#    Product_Price  Supermarket_Opening_Year Supermarket_Location_Type  \
# 0         357.54                      2005                 Cluster 3
# 1         355.79                      1994                 Cluster 3
# 2         350.79                      2014                 Cluster 2
# 3         355.04                      2016                 Cluster 3
# 4         354.79                      2011                 Cluster 2
#
#     Supermarket_Type  Product_Supermarket_Sales
# 0      Grocery Store                     709.08
# 1  Supermarket Type1                    6381.69
# ...

# %%
train_test_split = [data,test]

# %%
location = {'Cluster 3':2 , 'Cluster 2':1,'Cluster 1': 0 }
for dataset in train_test_split:
    dataset['Supermarket_Location_Type'] =dataset['Supermarket_Location_Type'].map(location)

# %%
data.head()
# Out:
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    1                  0.000000
#
#    Product_Price  Supermarket_Opening_Year  Supermarket_Location_Type  \
# 0         357.54                      2005                          2
# 1         355.79                      1994                          2
# 2         350.79                      2014                          1
# 3         355.04                      2016                          2
# 4         354.79                      2011                          1
#
#     Supermarket_Type  Product_Supermarket_Sales
# 0      Grocery Store                     709.08
# 1  Supermarket Type1                    6381.69
# ...

# %%
data['Product_Weight'].fillna(data.groupby('Product_Fat_Content')['Product_Weight'].transform('median'), inplace = True)

# %%
data['Supermarket_Type'].value_counts().unique
# Out:
# <bound method Series.unique of Supermarket Type1    3304
# Grocery Store         724
# Supermarket Type2     500
# Supermarket Type3     462
# Name: Supermarket_Type, dtype: int64>

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
labeled = LabelEncoder()

# %%
data['Supermarket_Type'] = labeled.fit_transform(data['Supermarket_Type'])

# %%
data.head()
# Out:
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    1                  0.000000
#
#    Product_Price  Supermarket_Opening_Year  Supermarket_Location_Type  \
# 0         357.54                      2005                          2
# 1         355.79                      1994                          2
# 2         350.79                      2014                          1
# 3         355.04                      2016                          2
# 4         354.79                      2011                          1
#
#    Supermarket_Type  Product_Supermarket_Sales
# 0                 0                     709.08
# 1                 1                    6381.69
# ...

# %%
OneHotEncoder = OneHotEncoder(categorical_features= [['Supermarket_Location_Type','Supermarket_Type']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-66770aa562d6> in <module>()
# ----> 1 OneHotEncoder = OneHotEncoder(categorical_features= [['Supermarket_Location_Type','Supermarket_Type']])
#
# TypeError: 'OneHotEncoder' object is not callable

# %%
x = OneHotEncoder.fit_transform(data).toarray()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-7ac45e6dc825> in <module>()
# ----> 1 x = OneHotEncoder.fit_transform(data).toarray()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1818     ind = np.arange(n_features)
#    1819     sel = np.zeros(n_features, dtype=bool)
# -> 1820     sel[np.asarray(selected)] = True
#    1821     not_sel = np.logical_not(sel)
#    1822     n_selected = np.sum(sel)
#
# ...

# %%
data.head()
# Out:
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    1                  0.000000
#
#    Product_Price  Supermarket_Opening_Year  Supermarket_Location_Type  \
# 0         357.54                      2005                          2
# 1         355.79                      1994                          2
# 2         350.79                      2014                          1
# 3         355.04                      2016                          2
# 4         354.79                      2011                          1
#
#    Supermarket_Type  Product_Supermarket_Sales
# 0                 0                     709.08
# 1                 1                    6381.69
# ...

# %%
a = data.values

# %%
pd.get_dummies(data['Supermarket_Location_Type'])
# Out:
#       0  1  2
# 0     0  0  1
# 1     0  0  1
# 2     0  1  0
# 3     0  0  1
# 4     0  1  0
# 5     0  1  0
# 6     0  0  1
# 7     0  0  1
# 8     0  1  0
# 9     1  0  0
# 10    0  0  1
# 11    0  1  0
# 12    1  0  0
# 13    0  1  0
# 14    0  0  1
# 15    1  0  0
# 16    0  0  1
# 17    1  0  0
# 18    1  0  0
# 19    0  0  1
# 20    1  0  0
# 21    0  1  0
# 22    0  1  0
# 23    1  0  0
# 24    0  1  0
# 25    0  1  0
# 26    0  1  0
# 27    1  0  0
# 28    0  0  1
# 29    0  0  1
# ...  .. .. ..
# 4960  1  0  0
# 4961  0  0  1
# 4962  0  0  1
# 4963  0  1  0
# 4964  1  0  0
# 4965  0  1  0
# 4966  0  1  0
# 4967  0  0  1
# 4968  0  0  1
# 4969  1  0  0
# 4970  0  0  1
# 4971  0  0  1
# 4972  0  1  0
# 4973  1  0  0
# 4974  0  0  1
# 4975  0  1  0
# 4976  0  0  1
# 4977  0  1  0
# 4978  0  1  0
# 4979  0  1  0
# 4980  0  0  1
# 4981  0  0  1
# 4982  1  0  0
# 4983  0  0  1
# 4984  0  0  1
# 4985  1  0  0
# 4986  0  0  1
# 4987  0  1  0
# 4988  1  0  0
# 4989  1  0  0
#
# ...
