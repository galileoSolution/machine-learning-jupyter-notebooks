# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('comedy.csv')

# %%
data
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83

# %%
data.describe()
data['length'] = data['Joke_identifier'].apply(len)

# %%
data.head()
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating  \
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83
#
#    length    d
# 0      22  [1]
# 1      22  [2]
# 2      19  [1]
# 3      19  [2]
# 4      22  [1]

# %%
data.corr()
# Out:
#           Rating    length
# Rating  1.000000 -0.227284
# length -0.227284  1.000000

# %%
data['d'] = data['Joke_identifier'].apply(lambda x:x.split()[-1:])

# %%
data.dtypes
# Out:
# Viewers_ID          object
# Joke_identifier     object
# Response_ID         object
# Rating             float64
# length               int64
# d                   object
# dtype: object

# %%
data['d'] = data['d'].astype(str)

# %%
data.head()
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating  \
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83
#
#    length      d
# 0      22  ['1']
# 1      22  ['2']
# 2      19  ['1']
# 3      19  ['2']
# 4      22  ['1']

# %%
data['d'] = data['d'].apply(lambda x: x.split()[1:])

# %%
data.head()
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating  \
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83
#
#    length   d
# 0      22  []
# 1      22  []
# 2      19  []
# 3      19  []
# 4      22  []

# %%
data['Joke_identifier'] = data['Joke_identifier'].astype(str)

# %%
data['Joke_identifier'] = data['Joke_identifier'].apply(lambda x: x[-1:])

# %%
data
# Out:
#        Viewers_ID Joke_identifier                    Response_ID  Rating  \
# 0              A1               1      A1_Klint De Drunk Enugu 1    0.11
# 1              A1               2      A1_Klint De Drunk Enugu 2   -4.64
# 2              A1               1         A1_Klint De Drunk PH 1   -3.39
# 3              A1               2         A1_Klint De Drunk PH 2    0.44
# 4              A1               1      A1_Klint De Drunk Lagos 1   -4.83
# 5              A1               2      A1_Klint De Drunk Lagos 2   -4.52
# 6              A1               3      A1_Klint De Drunk Lagos 3   -3.73
# 7              A1                     A1_Klint De Drunk Warri 1    -4.36
# 8              A1               2             A1_AliBaba Lagos 2   -4.39
# 9              A1               2          A1_AliBaba Aso Rock 2    4.39
# 10             A1               2             A1_AliBaba Abuja 2    4.39
# 11             A1               1                A1_AliBaba PH 1    4.39
# ...
