# %%
import pandas as pd

# %%
df = pd.read_csv('ecommerce-purchases-exercise-ipynb')
# Out:
# Empty DataFrame
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(1,10,6)

# %%
y = x**2

# %%
plt.plot(x,y)
plt.xlabel('tosino')
plt.ylabel('isimoney')
plt.title('eniMoney')
# Out:
# Text(0.5,1,'eniMoney')

# %%
fig = plt.figure()
axes1 = fig.add_axes([2,2,10,10])
axes2 = fig.add_axes([3,2,10,5])
axes1.plot(x,y)
axes2.plot(y,x)

# %%
plt.subplots(1,2,1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:1160: UserWarning: sharex argument to subplots() was an integer. Did you intend to use subplot() (without 's')?
#   "sharex argument to subplots() was an integer. "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7cb216ea2460> in <module>()
# ----> 1 plt.subplots(1,2,1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1177     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1178                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1179                        gridspec_kw=gridspec_kw)
#    1180     return fig, axs
#    1181
#
# ...

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r")

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
asea,fig = plt.subplots(nrows = 1,ncols =2)

for currentAxis in fig:
    currentAxis.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(1,10,6)
y = x**2
plt.plot(x,y,color ='red',linewidth = 1,marker = '*',markersize = 20,markerfacecolor = 'purple',
        markeredgecolor='blue',label = 'dhur')
plt.plot(y,x,label = 'get teh')
plt.legend(loc = 0)
fig = plt.figure()
ax =  fig.add_axes([10,200,10,10])
#ax.plot(x,y,color ='purple',linewidth = 20, alpha =600,linestyle = 'steps')

# %%
# matplotlib exercises

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax  = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5,1,'title')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y)
ax2.plot(x,y)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 =  fig.add_axes([0.2,0.5,.4,.4])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax1.plot(x,z)
ax1.set_xlabel('x')
ax1.set_ylabel('z')
#ax1.set_title('dhoom')
ax1.set_xlim([0,100])
ax2 =  fig.add_axes([0.2,0.5,.4,.4])
ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30, 50)

# %%
fig,axes = plt.subplots(nrows =1 ,ncols =2)
axes[0].plot(x,y,lw=2,ls='--',color = 'blue')
axes[1].plot(x,z,color = 'red',lw = 4)

# %%
fig

# %%
fig,axes = plt.subplots(nrows =1 ,ncols =2,figsize = (8,1))
axes[0].plot(x,y,lw=2,color = 'blue')
axes[1].plot(x,z,color = 'red',lw = 1.5,ls='--')
