# %%
import numpy as py
import pandas as pd

# %%
d = {1:[2,3,4,5],2:[6,5,7,8],3:[9,0,9,8]}

# %%
f = pd.DataFrame(d)

# %%
# Out:
#    1  2  3
# 0  2  6  9
# 1  3  5  0
# 2  4  7  9
# 3  5  8  8

# %%
f.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a5366472cd52> in <module>()
# ----> 1 f.reset_index()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    3377                 # to ndarray and maybe infer different dtype
#    3378                 level_values = _maybe_casted_values(lev, lab)
# -> 3379                 new_obj.insert(0, name, level_values)
#    3380
#    3381         new_obj.index = new_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    2611         value = self._sanitize_column(column, value, broadcast=False)
#    2612         self._data.insert(loc, column, value,
# -> 2613                           allow_duplicates=allow_duplicates)
#    2614
# ...

# %%
f
# Out:
#    level_0  index  1  2  3
# 0        0      0  2  6  9
# 1        1      1  3  5  0
# 2        2      2  4  7  9
# 3        3      3  5  8  8

# %%
f.index.names()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c07ba1f2e613> in <module>()
# ----> 1 f.index.names()
#
# TypeError: 'FrozenList' object is not callable

# %%
import numpy as np
import pandas as pd

# %%
data = {2:[1,1,2,2],1:[1,2,3,4],3:[90,56,45,44]}

# %%
data
# Out:
# {1: [1, 2, 3, 4], 2: [1, 1, 2, 2], 3: [90, 56, 45, 44]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    1  2   3
# 0  1  1  90
# 1  2  1  56
# 2  3  2  45
# 3  4  2  44

# %%
 df.reset_index()
# Out:
#    index  1  2   3
# 0      0  1  1  90
# 1      1  2  1  56
# 2      2  3  2  45
# 3      3  4  2  44

# %%
df.groupby(2).describe().transpose()
# Out:
# 2                1          2
# 1 count   2.000000   2.000000
#   mean    1.500000   3.500000
#   std     0.707107   0.707107
#   min     1.000000   3.000000
#   25%     1.250000   3.250000
#   50%     1.500000   3.500000
#   75%     1.750000   3.750000
#   max     2.000000   4.000000
# 3 count   2.000000   2.000000
#   mean   73.000000  44.500000
#   std    24.041631   0.707107
#   min    56.000000  44.000000
#   25%    64.500000  44.250000
#   50%    73.000000  44.500000
#   75%    81.500000  44.750000
#   max    90.000000  45.000000

# %%
by2.sum()
# Out:
#    1    3
# 2
# 1  3  146
# 2  7   89

# %%
import numpy as np
import pandas as ps

# %%
df = pd.DataFrame({'col':[1,1,2,2],'col2':[444,222,666,444],'col3':['abc','def','ghi','xyz']})

# %%
df.head()
# Out:
#    col  col2 col3
# 0    1   444  abc
# 1    1   222  def
# 2    2   666  ghi
# 3    2   444  xyz

# %%
df['col'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['col'].value_counts()
# Out:
# 2    2
# 1    2
# Name: col, dtype: int64

# %%
df
# Out:
#    col  col2 col3
# 0    1   444  abc
# 1    1   222  def
# 2    2   666  ghi
# 3    2   444  xyz

# %%
df[df['col']>1]
# Out:
#    col  col2 col3
# 2    2   666  ghi
# 3    2   444  xyz

# %%
def times3(x):
    return x*3

# %%
df['col'].apply(times3)
# Out:
# 0    3
# 1    3
# 2    6
# 3    6
# Name: col, dtype: int64

# %%
df
# Out:
#    col  col2 col3
# 0    1   444  abc
# 1    1   222  def
# 2    2   666  ghi
# 3    2   444  xyz

# %%
df.sort_values('col2')
# Out:
#    col  col2 col3
# 1    1   222  def
# 0    1   444  abc
# 3    2   444  xyz
# 2    2   666  ghi

# %%
df
# Out:
#    col  col2 col3
# 0    1   444  abc
# 1    1   222  def
# 2    2   666  ghi
# 3    2   444  xyz

# %%
 df = pd.DataFrame({'col':[1,1,2,2],'col2':[444,444,666,666],'col3':['x','y','x','y'],'col4':[1,2,3,4]})

# %%
df
# Out:
#    col  col2 col3  col4
# 0    1   444    x     1
# 1    1   444    y     2
# 2    2   666    x     3
# 3    2   666    y     4

# %%
df.pivot_table(values= 'col4',index = ['col','col2'],columns = ['col3'])
# Out:
# col3      x  y
# col col2
# 1   444   1  2
# 2   666   3  4

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\OLALEYE ENIOLA\\Desktop\\algo_py'

# %%
pd.read_csv('example.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-103-4eca52408889> in <module>()
# ----> 1 pd.read_csv('example.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
df
# Out:
#    col  col2 col3  col4
# 0    1   444    x     1
# 1    1   444    y     2
# 2    2   666    x     3
# 3    2   666    y     4

# %%
df.to_csv("my_output")

# %%
pd.read_csv('my_output')
# Out:
#    Unnamed: 0  col  col2 col3  col4
# 0           0    1   444    x     1
# 1           1    1   444    y     2
# 2           2    2   666    x     3
# 3           3    2   666    y     4

# %%
df.to_csv("my_output",index = False)

# %%
pd.read_csv("my_output")
# Out:
#    col  col2 col3  col4
# 0    1   444    x     1
# 1    1   444    y     2
# 2    2   666    x     3
# 3    2   666    y     4

# %%
df
# Out:
#    col  col2 col3  col4
# 0    1   444    x     1
# 1    1   444    y     2
# 2    2   666    x     3
# 3    2   666    y     4

# %%
 pd.read_excel('example.xlsx',sheetname = 'Sheet1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#     A   B   C   D
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
df = df.to_csv('files',index )

# %%
df
