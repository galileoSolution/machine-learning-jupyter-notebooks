# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
dfa  = pd.read_csv('train.csv')

# %%
dfa.head()
# Out:
#    S/N Gender  Age Location famsize Pstatus  Medu  Fedu  traveltime  \
# 0    1      F   13        U     GT3       A     4     4           2
# 1    2      F   12        U     GT3       T     1     1           1
# 2    3      F   10        U     LE3       T     1     1           1
# 3    4      F   10        U     GT3       T     4     2           1
# 4    5      F   11        U     GT3       T     3     3           1
#
#    studytime  ...    paid activities nursery higher internet famrel freetime  \
# 0          2  ...      no         no     yes    yes       no      4        3
# 1          2  ...      no         no      no    yes      yes      5        3
# 2          2  ...      no         no     yes    yes      yes      4        3
# 3          3  ...      no        yes     yes    yes      yes      3        2
# 4          2  ...      no         no     yes    yes       no      4        3
#
#   health  absences  Score
# 0      3         4     22
# 1      3         2     31
# ...

# %%
df['famrel'].unique()
# Out:
# array([4, 5, 3, 1, 2], dtype=int64)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap = 'viridis')
# no missing value in the data set

# %%
new = pd.get_dummies(df['Gender'],drop_first=True)

# %%
df['Location'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
new.head()
# Out:
#    M
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
new2 =  pd.get_dummies(df['Location'],drop_first = True)

# %%
new2.head()
# Out:
#    U
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
df['famsize'].unique()
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
new3 = pd.get_dummies(df['famsize'],drop_first = True)

# %%
new3.head()
# Out:
#    LE3
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0

# %%
df['Pstatus'].unique()
# Out:
# array(['A', 'T'], dtype=object)

# %%
new4 = pd.get_dummies(df['Pstatus'], drop_first = True)

# %%
new4.head()
# Out:
#    T
# 0  0
# 1  1
# 2  1
# 3  1
# 4  1

# %%
df['paid'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
new4.head()
# Out:
#    yes
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %%
new5 = pd.get_dummies(df['activities'], drop_first =  True)

# %%
new6 = pd.get_dummies(df['nursery'], drop_first =  True)

# %%
new7 = pd.get_dummies(df['higher'], drop_first =  True)

# %%
new8 = pd.get_dummies(df['internet'], drop_first =  True)

# %%
new9 = pd.get_dummies(df['schoolsup'], drop_first =  True)

# %%
new10 = pd.get_dummies(df['famsup'], drop_first =  True)

# %%
df.head(2)
# Out:
#    S/N  Age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    1   13     4     4           2          2         0       4         3
# 1    2   12     1     1           1          2         0       5         3
#
#    health ...   M  U  LE3  yes  yes  yes  yes  yes  yes  yes
# 0       3 ...   0  1    0    0    0    1    1    0    1    0
# 1       3 ...   0  1    0    0    0    0    1    1    0    1
#
# [2 rows x 22 columns]

# %%
dfa.head()
# Out:
#    S/N Gender  Age Location famsize Pstatus  Medu  Fedu  traveltime  \
# 0    1      F   13        U     GT3       A     4     4           2
# 1    2      F   12        U     GT3       T     1     1           1
# 2    3      F   10        U     LE3       T     1     1           1
# 3    4      F   10        U     GT3       T     4     2           1
# 4    5      F   11        U     GT3       T     3     3           1
#
#    studytime  ...    paid activities nursery higher internet famrel freetime  \
# 0          2  ...      no         no     yes    yes       no      4        3
# 1          2  ...      no         no      no    yes      yes      5        3
# 2          2  ...      no         no     yes    yes      yes      4        3
# 3          3  ...      no        yes     yes    yes      yes      3        2
# 4          2  ...      no         no     yes    yes       no      4        3
#
#   health  absences  Score
# 0      3         4     22
# 1      3         2     31
# ...

# %%
df.drop(['schoolsup', 'famsup'],axis = 1, inplace =  True)

# %%
df.head()
# Out:
#    S/N  Age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    1   13     4     4           2          2         0       4         3
# 1    2   12     1     1           1          2         0       5         3
# 2    3   10     1     1           1          2         0       4         3
# 3    4   10     4     2           1          3         0       3         2
# 4    5   11     3     3           1          2         0       4         3
#
#    health  absences  Score
# 0       3         4     22
# 1       3         2     31
# 2       3         6     37
# 3       5         0     42
# 4       5         0     37

# %%
df =  pd.concat([df, new,new2,new3,new4,new5,new6,new7,new8,new9,new10],  axis =1)

# %%
df
# Out:
#      S/N  Age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0      1   13     4     4           2          2         0       4         3
# 1      2   12     1     1           1          2         0       5         3
# 2      3   10     1     1           1          2         0       4         3
# 3      4   10     4     2           1          3         0       3         2
# 4      5   11     3     3           1          2         0       4         3
# 5      6   11     4     3           1          2         0       5         4
# 6      7   11     2     2           1          2         0       4         4
# 7      8   12     4     4           2          2         0       4         1
# 8      9   10     3     2           1          2         0       4         2
# 9     10   10     3     4           1          2         0       5         5
# 10    11   10     4     4           1          2         0       3         3
# ...
