# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.read_csv('test_fresh.xls')

# %%
test['Product_Weight'].fillna(test.groupby('Product_Fat_Content')['Product_Weight'].transform('mean'), inplace = True)

# %%
train_test_split = [test]
supermarket_size = {'High': 2,'Medium': 1,'Small':0}
for dataset in train_test_split:
    dataset['Supermarket _Size'] =dataset['Supermarket _Size'].map(supermarket_size)

# %%
test['Supermarket _Size'].fillna(test.groupby('Product_Type')['Supermarket _Size'].transform('median'), inplace = True)

# %%
test.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA59            CHUKWUDI010              DRA59_CHUKWUDI010
# 1              DRA59            CHUKWUDI013              DRA59_CHUKWUDI013
# 2              DRB01            CHUKWUDI013              DRB01_CHUKWUDI013
# 3              DRB13            CHUKWUDI010              DRB13_CHUKWUDI010
# 4              DRB13            CHUKWUDI013              DRB13_CHUKWUDI013
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
# ...

# %%
test['f'] = test.Product_Weight.astype(object)

# %%
test.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA59            CHUKWUDI010              DRA59_CHUKWUDI010
# 1              DRA59            CHUKWUDI013              DRA59_CHUKWUDI013
# 2              DRB01            CHUKWUDI013              DRB01_CHUKWUDI013
# 3              DRB13            CHUKWUDI010              DRB13_CHUKWUDI010
# 4              DRB13            CHUKWUDI013              DRB13_CHUKWUDI013
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
# ...

# %%
test['f'] = test['f'].astype(str)

# %%
test['f'] = test['f'].apply(lambda x: x.split('.')[0])

# %%
test.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA59            CHUKWUDI010              DRA59_CHUKWUDI010
# 1              DRA59            CHUKWUDI013              DRA59_CHUKWUDI013
# 2              DRB01            CHUKWUDI013              DRB01_CHUKWUDI013
# 3              DRB13            CHUKWUDI010              DRB13_CHUKWUDI010
# 4              DRB13            CHUKWUDI013              DRB13_CHUKWUDI013
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
# ...

# %%
test['f'] = test['f'].astype(float)

# %%
test['b'] =  test['Product_Weight'] - test['f']

# %%
test.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA59            CHUKWUDI010              DRA59_CHUKWUDI010
# 1              DRA59            CHUKWUDI013              DRA59_CHUKWUDI013
# 2              DRB01            CHUKWUDI013              DRB01_CHUKWUDI013
# 3              DRB13            CHUKWUDI010              DRB13_CHUKWUDI010
# 4              DRB13            CHUKWUDI013              DRB13_CHUKWUDI013
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
# ...

# %%
test.drop(['Product_Supermarket_Identifier','Product_Identifier','Supermarket_Identifier','f'], axis =1, inplace = True)

# %%
test.head()
# Out:
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year  Supermarket _Size  \
# 0         459.98                      2005                1.0
# 1         464.98                      1994                2.0
# 2         477.38                      1994                2.0
# 3         472.63                      2005                1.0
# 4         473.13                      1994                2.0
#
#   Supermarket_Location_Type   Supermarket_Type      b
# 0                 Cluster 3      Grocery Store  0.270
# ...

# %%
test['a'] = test['Product_Price'].astype(str)

# %%
test['f'] = test['a'].apply(lambda x: x.split('.')[0])

# %%
test.head()
# Out:
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year  Supermarket _Size  \
# 0         459.98                      2005                1.0
# 1         464.98                      1994                2.0
# 2         477.38                      1994                2.0
# 3         472.63                      2005                1.0
# 4         473.13                      1994                2.0
#
#   Supermarket_Location_Type   Supermarket_Type      b       a    f
# ...

# %%
test['f'] = test['f'].astype(float)

# %%
test['d'] =  test['Product_Price'] - test['f']

# %%
test.head()
# Out:
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year  Supermarket _Size  \
# 0         459.98                      2005                1.0
# 1         464.98                      1994                2.0
# 2         477.38                      1994                2.0
# 3         472.63                      2005                1.0
# 4         473.13                      1994                2.0
#
#   Supermarket_Location_Type   Supermarket_Type      b       a      f     d
# ...

# %%
test.drop(['a','f'],axis = 1, inplace = True)

# %%
test.head()
# Out:
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0           8.270          Normal Fat                  0.214125  Soft Drinks
# 1           8.270          Normal Fat                  0.127821  Soft Drinks
# 2           7.390             Low Fat                  0.082171  Soft Drinks
# 3           6.115          Normal Fat                  0.011791  Soft Drinks
# 4           6.115          Normal Fat                  0.007038  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year  Supermarket _Size  \
# 0         459.98                      2005                1.0
# 1         464.98                      1994                2.0
# 2         477.38                      1994                2.0
# 3         472.63                      2005                1.0
# 4         473.13                      1994                2.0
#
#   Supermarket_Location_Type   Supermarket_Type      b     d
# 0                 Cluster 3      Grocery Store  0.270  0.98
# ...

# %%
dumm1 = pd.get_dummies(test['Product_Fat_Content'])
dumm2 = pd.get_dummies(test['Supermarket_Location_Type'])
dumm3 = pd.get_dummies(test['Supermarket_Type'])

# %%
test.drop(['Supermarket_Location_Type','Product_Fat_Content','Supermarket_Type','Product_Type'],axis = 1, inplace = True)

# %%
test.head()
# Out:
#    Product_Weight  Product_Shelf_Visibility  Product_Price  \
# 0           8.270                  0.214125         459.98
# 1           8.270                  0.127821         464.98
# 2           7.390                  0.082171         477.38
# 3           6.115                  0.011791         472.63
# 4           6.115                  0.007038         473.13
#
#    Supermarket_Opening_Year  Supermarket _Size      b     d
# 0                      2005                1.0  0.270  0.98
# 1                      1994                2.0  0.270  0.98
# 2                      1994                2.0  0.390  0.38
# 3                      2005                1.0  0.115  0.63
# 4                      1994                2.0  0.115  0.13

# %%
test = pd.concat([test,dumm1,dumm2,dumm3],axis = 1)

# %%
test.head()
# Out:
#    Product_Weight  Product_Shelf_Visibility  Product_Price  \
# 0           8.270                  0.214125         459.98
# 1           8.270                  0.127821         464.98
# 2           7.390                  0.082171         477.38
# 3           6.115                  0.011791         472.63
# 4           6.115                  0.007038         473.13
#
#    Supermarket_Opening_Year  Supermarket _Size      b     d  Low Fat  \
# 0                      2005                1.0  0.270  0.98        0
# 1                      1994                2.0  0.270  0.98        0
# 2                      1994                2.0  0.390  0.38        1
# 3                      2005                1.0  0.115  0.63        0
# 4                      1994                2.0  0.115  0.13        0
#
#    Normal Fat  Ultra Low fat  Cluster 1  Cluster 2  Cluster 3  Grocery Store  \
# 0           1              0          0          0          1              1
# ...

# %%
test.to_csv('gbefun.csv')
